# %% [markdown]
# <a href="https://colab.research.google.com/github/susooo/data-collection/blob/main/HTML_%ED%81%AC%EB%A1%A4%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://developer.mozilla.org/ko/docs/Web/HTML/Element')
res.content
# Out:
# b'<!doctype html><html lang="en-US" prefix="og: https://ogp.me/ns#"><head><meta charset="utf-8"/><meta name="viewport" content="width=device-width,initial-scale=1"/><link rel="icon" href="/favicon-48x48.cbbd161b.png"/><link rel="apple-touch-icon" href="/apple-touch-icon.6803c6f0.png"/><meta name="theme-color" content="#ffffff"/><link rel="manifest" href="/manifest.56b1cedc.json"/><link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="MDN Web Docs"/><script>Array.prototype.flat&&Array.prototype.includes||document.write(\'<script src="https://polyfill.io/v3/polyfill.min.js?features=Array.prototype.flat%2Ces6"><\\/script>\')</script><title>HTML \xec\x9a\x94\xec\x86\x8c \xec\xb0\xb8\xea\xb3\xa0\xec\x84\x9c - HTML: Hypertext Markup Language | MDN</title><link rel="alternate" title=Element href="https://developer.mozilla.org/de/docs/Web/HTML/Element" hreflang="de"/><link rel="alternate" title=HTML elements reference href="https://developer.mozilla.org
# ...

# %%
soup = BeautifulSoup(res.content, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
soup = BeautifulSoup(res.content, "html.parser")

# %%
mydata = soup.find('title')
print(mydata.get_text())
# Out:
# HTML 요소 참고서 - HTML: Hypertext Markup Language | MDN

# %%
#1 라이브러리 임포트
import requests
from bs4 import BeautifulSoup
#2 웹페이지 지정
html = """
<html> 
  <body>
    <h1 id='title'>[1]크롤링이란?</h1>
    <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p>
    <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
  </body>
</html>
"""
#3 웹페이지 파싱
soup = BeautifulSoup(html, "html.parser")
#4 태그로 검색하여 필요한 html 코드 추출
data = soup.find('h1')
print(data)

#5 html로부터 필요한 데이터 추출
print(data.string)
print(data.get_text())
# Out:
# <h1 id="title">[1]크롤링이란?</h1>
# [1]크롤링이란?
# [1]크롤링이란?

# %%
#6 동일한 태그가 여러개인 경우
data1 = soup.find('p', class_='cssstyle')
data2 = soup.find('p', 'cssstyle')
data3 = soup.find('p', attrs={'align':'center'})
data4 = soup.find(id='body')

print(data1.string)
print(data2.string)
print(data3.string)
print(data4.string)
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# 웹페이지에서 필요한 데이터를 추출하는 것
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %%
#7 해당 태그의 모든 문장 가져오기
paragraph_data = soup.find_all('p')
for paragraph in paragraph_data:
  print(paragraph.get_text())
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달
